# %%
import pandas as pd

# %%
df = pd.read_csv('all_data_augmented_bnf16.csv')
train_data = pd.read_csv('train.csv')
val_data = pd.read_csv('val.csv')
test_data = pd.read_csv('test.csv')

# %%
df['label'].value_counts()
# Out:
# label
# anger      2100
# fear       2100
# joy        2100
# love       2100
# neutral    2100
# sad        2100
# Name: count, dtype: int64

# %%
train_data['label'].value_counts()
# Out:
# label
# love       1492
# fear       1488
# anger      1478
# sad        1462
# joy        1450
# neutral    1450
# Name: count, dtype: int64

# %%
val_data['label'].value_counts()
# Out:
# label
# sad        339
# joy        331
# neutral    328
# love       307
# anger      306
# fear       279
# Name: count, dtype: int64

# %%
test_data['label'].value_counts()
# Out:
# label
# fear       333
# neutral    322
# joy        319
# anger      316
# love       301
# sad        299
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Data
categories = ['Neutral', 'Joy', 'Anger', 'Sad', 'Fear', 'Love']
train_counts = [1492, 1488, 1478, 1462, 1450, 1450]
val_counts = [339, 331, 328, 307, 306, 279]
test_counts = [333, 322, 319, 316, 301, 299]

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Train Bar Chart
axes[0].bar(categories, train_counts, color='blue')
axes[0].set_title('Train Data Distribution')
axes[0].set_xlabel('Emotion')
axes[0].set_ylabel('Count')

# Validation Bar Chart
axes[1].bar(categories, val_counts, color='green')
axes[1].set_title('Validation Data Distribution')
axes[1].set_xlabel('Emotion')
axes[1].set_ylabel('Count')

# Test Bar Chart
axes[2].bar(categories, test_counts, color='red')
axes[2].set_title('Test Data Distribution')
axes[2].set_xlabel('Emotion')
axes[2].set_ylabel('Count')

# Display the plots
plt.tight_layout()
plt.show()
