# %% [markdown]
# <a href="https://colab.research.google.com/github/Latifmmhd/Augmentasi-Data-Indonesia-Tweet/blob/main/get_best_params.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip best_params.zip
# Out:
# Archive:  best_params.zip
#    creating: best_params/
#    creating: best_params/checkpoint-2500/
#   inflating: best_params/checkpoint-2500/adapter_model.safetensors
#   inflating: best_params/checkpoint-2500/rng_state.pth
#   inflating: best_params/checkpoint-2500/tokenizer_config.json
#   inflating: best_params/checkpoint-2500/special_tokens_map.json
#   inflating: best_params/checkpoint-2500/optimizer.pt
#   inflating: best_params/checkpoint-2500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-2500/scheduler.pt
#   inflating: best_params/checkpoint-2500/tokenizer.json
#   inflating: best_params/checkpoint-2500/README.md
#   inflating: best_params/checkpoint-2500/training_args.bin
#   inflating: best_params/checkpoint-2500/adapter_config.json
#   inflating: best_params/checkpoint-2500/vocab.txt
#   inflating: best_params/checkpoint-2500/trainer_state.json
#    creating: best_params/checkpoint-2538/
#   inflating: best_params/checkpoint-2538/adapter_model.safetensors
#   inflating: best_params/checkpoint-2538/rng_state.pth
#   inflating: best_params/checkpoint-2538/tokenizer_config.json
#   inflating: best_params/checkpoint-2538/special_tokens_map.json
#   inflating: best_params/checkpoint-2538/optimizer.pt
#   inflating: best_params/checkpoint-2538/scheduler.pt
#   inflating: best_params/checkpoint-2538/tokenizer.json
#   inflating: best_params/checkpoint-2538/README.md
#   inflating: best_params/checkpoint-2538/training_args.bin
#   inflating: best_params/checkpoint-2538/adapter_config.json
#   inflating: best_params/checkpoint-2538/vocab.txt
#   inflating: best_params/checkpoint-2538/trainer_state.json
#    creating: best_params/checkpoint-1128/
#   inflating: best_params/checkpoint-1128/adapter_model.safetensors
#   inflating: best_params/checkpoint-1128/rng_state.pth
#   inflating: best_params/checkpoint-1128/tokenizer_config.json
#   inflating: best_params/checkpoint-1128/special_tokens_map.json
#   inflating: best_params/checkpoint-1128/optimizer.pt
#   inflating: best_params/checkpoint-1128/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-1128/scheduler.pt
#   inflating: best_params/checkpoint-1128/tokenizer.json
#   inflating: best_params/checkpoint-1128/README.md
#   inflating: best_params/checkpoint-1128/training_args.bin
#   inflating: best_params/checkpoint-1128/adapter_config.json
#   inflating: best_params/checkpoint-1128/trainer_state.json
#    creating: best_params/checkpoint-282/
#   inflating: best_params/checkpoint-282/adapter_model.safetensors
#   inflating: best_params/checkpoint-282/rng_state.pth
#   inflating: best_params/checkpoint-282/tokenizer_config.json
#   inflating: best_params/checkpoint-282/special_tokens_map.json
#   inflating: best_params/checkpoint-282/optimizer.pt
#   inflating: best_params/checkpoint-282/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-282/scheduler.pt
#   inflating: best_params/checkpoint-282/tokenizer.json
#   inflating: best_params/checkpoint-282/README.md
#   inflating: best_params/checkpoint-282/training_args.bin
#   inflating: best_params/checkpoint-282/adapter_config.json
#   inflating: best_params/checkpoint-282/vocab.txt
#   inflating: best_params/checkpoint-282/trainer_state.json
#    creating: best_params/checkpoint-1126/
#   inflating: best_params/checkpoint-1126/adapter_model.safetensors
#   inflating: best_params/checkpoint-1126/rng_state.pth
#   inflating: best_params/checkpoint-1126/tokenizer_config.json
#   inflating: best_params/checkpoint-1126/special_tokens_map.json
#   inflating: best_params/checkpoint-1126/optimizer.pt
#   inflating: best_params/checkpoint-1126/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-1126/scheduler.pt
#   inflating: best_params/checkpoint-1126/tokenizer.json
#   inflating: best_params/checkpoint-1126/README.md
#   inflating: best_params/checkpoint-1126/training_args.bin
#   inflating: best_params/checkpoint-1126/adapter_config.json
#   inflating: best_params/checkpoint-1126/trainer_state.json
#    creating: best_params/checkpoint-6500/
#   inflating: best_params/checkpoint-6500/adapter_model.safetensors
#   inflating: best_params/checkpoint-6500/rng_state.pth
#   inflating: best_params/checkpoint-6500/tokenizer_config.json
#   inflating: best_params/checkpoint-6500/special_tokens_map.json
#   inflating: best_params/checkpoint-6500/optimizer.pt
#   inflating: best_params/checkpoint-6500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-6500/scheduler.pt
#   inflating: best_params/checkpoint-6500/tokenizer.json
#   inflating: best_params/checkpoint-6500/README.md
#   inflating: best_params/checkpoint-6500/training_args.bin
#   inflating: best_params/checkpoint-6500/adapter_config.json
#   inflating: best_params/checkpoint-6500/vocab.txt
#   inflating: best_params/checkpoint-6500/trainer_state.json
#    creating: best_params/checkpoint-846/
#   inflating: best_params/checkpoint-846/adapter_model.safetensors
#   inflating: best_params/checkpoint-846/rng_state.pth
#   inflating: best_params/checkpoint-846/tokenizer_config.json
#   inflating: best_params/checkpoint-846/special_tokens_map.json
#   inflating: best_params/checkpoint-846/optimizer.pt
#   inflating: best_params/checkpoint-846/scheduler.pt
#   inflating: best_params/checkpoint-846/tokenizer.json
#   inflating: best_params/checkpoint-846/README.md
#   inflating: best_params/checkpoint-846/training_args.bin
#   inflating: best_params/checkpoint-846/adapter_config.json
#   inflating: best_params/checkpoint-846/vocab.txt
#   inflating: best_params/checkpoint-846/trainer_state.json
#   inflating: best_params/p-indobertweet.json
#    creating: best_params/checkpoint-4000/
#   inflating: best_params/checkpoint-4000/adapter_model.safetensors
#   inflating: best_params/checkpoint-4000/rng_state.pth
#   inflating: best_params/checkpoint-4000/tokenizer_config.json
#   inflating: best_params/checkpoint-4000/special_tokens_map.json
#   inflating: best_params/checkpoint-4000/optimizer.pt
#   inflating: best_params/checkpoint-4000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-4000/scheduler.pt
#   inflating: best_params/checkpoint-4000/tokenizer.json
#   inflating: best_params/checkpoint-4000/README.md
#   inflating: best_params/checkpoint-4000/training_args.bin
#   inflating: best_params/checkpoint-4000/adapter_config.json
#   inflating: best_params/checkpoint-4000/vocab.txt
#   inflating: best_params/checkpoint-4000/trainer_state.json
#    creating: best_params/checkpoint-6750/
#   inflating: best_params/checkpoint-6750/adapter_model.safetensors
#   inflating: best_params/checkpoint-6750/rng_state.pth
#   inflating: best_params/checkpoint-6750/tokenizer_config.json
#   inflating: best_params/checkpoint-6750/special_tokens_map.json
#   inflating: best_params/checkpoint-6750/optimizer.pt
#   inflating: best_params/checkpoint-6750/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-6750/scheduler.pt
#   inflating: best_params/checkpoint-6750/tokenizer.json
#   inflating: best_params/checkpoint-6750/README.md
#   inflating: best_params/checkpoint-6750/training_args.bin
#   inflating: best_params/checkpoint-6750/adapter_config.json
#   inflating: best_params/checkpoint-6750/vocab.txt
#   inflating: best_params/checkpoint-6750/trainer_state.json
#   inflating: best_params/xlm-r-base.json
#    creating: best_params/checkpoint-7500/
#   inflating: best_params/checkpoint-7500/adapter_model.safetensors
#   inflating: best_params/checkpoint-7500/rng_state.pth
#   inflating: best_params/checkpoint-7500/tokenizer_config.json
#   inflating: best_params/checkpoint-7500/special_tokens_map.json
#   inflating: best_params/checkpoint-7500/optimizer.pt
#   inflating: best_params/checkpoint-7500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-7500/scheduler.pt
#   inflating: best_params/checkpoint-7500/tokenizer.json
#   inflating: best_params/checkpoint-7500/README.md
#   inflating: best_params/checkpoint-7500/training_args.bin
#   inflating: best_params/checkpoint-7500/adapter_config.json
#   inflating: best_params/checkpoint-7500/vocab.txt
#   inflating: best_params/checkpoint-7500/trainer_state.json
#    creating: best_params/checkpoint-500/
#   inflating: best_params/checkpoint-500/adapter_model.safetensors
#   inflating: best_params/checkpoint-500/rng_state.pth
#   inflating: best_params/checkpoint-500/tokenizer_config.json
#   inflating: best_params/checkpoint-500/special_tokens_map.json
#   inflating: best_params/checkpoint-500/optimizer.pt
#   inflating: best_params/checkpoint-500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-500/scheduler.pt
#   inflating: best_params/checkpoint-500/tokenizer.json
#   inflating: best_params/checkpoint-500/README.md
#   inflating: best_params/checkpoint-500/training_args.bin
#   inflating: best_params/checkpoint-500/adapter_config.json
#   inflating: best_params/checkpoint-500/vocab.txt
#   inflating: best_params/checkpoint-500/trainer_state.json
#    creating: best_params/checkpoint-5000/
#   inflating: best_params/checkpoint-5000/adapter_model.safetensors
#   inflating: best_params/checkpoint-5000/rng_state.pth
#   inflating: best_params/checkpoint-5000/tokenizer_config.json
#   inflating: best_params/checkpoint-5000/special_tokens_map.json
#   inflating: best_params/checkpoint-5000/optimizer.pt
#   inflating: best_params/checkpoint-5000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-5000/scheduler.pt
#   inflating: best_params/checkpoint-5000/tokenizer.json
#   inflating: best_params/checkpoint-5000/README.md
#   inflating: best_params/checkpoint-5000/training_args.bin
#   inflating: best_params/checkpoint-5000/adapter_config.json
#   inflating: best_params/checkpoint-5000/vocab.txt
#   inflating: best_params/checkpoint-5000/trainer_state.json
#    creating: best_params/checkpoint-564/
#   inflating: best_params/checkpoint-564/adapter_model.safetensors
#   inflating: best_params/checkpoint-564/rng_state.pth
#   inflating: best_params/checkpoint-564/tokenizer_config.json
#   inflating: best_params/checkpoint-564/special_tokens_map.json
#   inflating: best_params/checkpoint-564/optimizer.pt
#   inflating: best_params/checkpoint-564/scheduler.pt
#   inflating: best_params/checkpoint-564/tokenizer.json
#   inflating: best_params/checkpoint-564/README.md
#   inflating: best_params/checkpoint-564/training_args.bin
#   inflating: best_params/checkpoint-564/adapter_config.json
#   inflating: best_params/checkpoint-564/vocab.txt
#   inflating: best_params/checkpoint-564/trainer_state.json
#    creating: best_params/checkpoint-3500/
#   inflating: best_params/checkpoint-3500/adapter_model.safetensors
#   inflating: best_params/checkpoint-3500/rng_state.pth
#   inflating: best_params/checkpoint-3500/tokenizer_config.json
#   inflating: best_params/checkpoint-3500/special_tokens_map.json
#   inflating: best_params/checkpoint-3500/optimizer.pt
#   inflating: best_params/checkpoint-3500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-3500/scheduler.pt
#   inflating: best_params/checkpoint-3500/tokenizer.json
#   inflating: best_params/checkpoint-3500/README.md
#   inflating: best_params/checkpoint-3500/training_args.bin
#   inflating: best_params/checkpoint-3500/adapter_config.json
#   inflating: best_params/checkpoint-3500/vocab.txt
#   inflating: best_params/checkpoint-3500/trainer_state.json
#    creating: best_params/checkpoint-563/
#   inflating: best_params/checkpoint-563/adapter_model.safetensors
#   inflating: best_params/checkpoint-563/rng_state.pth
#   inflating: best_params/checkpoint-563/tokenizer_config.json
#   inflating: best_params/checkpoint-563/special_tokens_map.json
#   inflating: best_params/checkpoint-563/optimizer.pt
#   inflating: best_params/checkpoint-563/scheduler.pt
#   inflating: best_params/checkpoint-563/tokenizer.json
#   inflating: best_params/checkpoint-563/README.md
#   inflating: best_params/checkpoint-563/training_args.bin
#   inflating: best_params/checkpoint-563/adapter_config.json
#   inflating: best_params/checkpoint-563/vocab.txt
#   inflating: best_params/checkpoint-563/trainer_state.json
#    creating: best_params/checkpoint-705/
#   inflating: best_params/checkpoint-705/adapter_model.safetensors
#   inflating: best_params/checkpoint-705/rng_state.pth
#   inflating: best_params/checkpoint-705/tokenizer_config.json
#   inflating: best_params/checkpoint-705/special_tokens_map.json
#   inflating: best_params/checkpoint-705/optimizer.pt
#   inflating: best_params/checkpoint-705/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-705/scheduler.pt
#   inflating: best_params/checkpoint-705/tokenizer.json
#   inflating: best_params/checkpoint-705/README.md
#   inflating: best_params/checkpoint-705/training_args.bin
#   inflating: best_params/checkpoint-705/adapter_config.json
#   inflating: best_params/checkpoint-705/trainer_state.json
#    creating: best_params/checkpoint-2815/
#   inflating: best_params/checkpoint-2815/adapter_model.safetensors
#   inflating: best_params/checkpoint-2815/rng_state.pth
#   inflating: best_params/checkpoint-2815/tokenizer_config.json
#   inflating: best_params/checkpoint-2815/special_tokens_map.json
#   inflating: best_params/checkpoint-2815/optimizer.pt
#   inflating: best_params/checkpoint-2815/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-2815/scheduler.pt
#   inflating: best_params/checkpoint-2815/tokenizer.json
#   inflating: best_params/checkpoint-2815/README.md
#   inflating: best_params/checkpoint-2815/training_args.bin
#   inflating: best_params/checkpoint-2815/adapter_config.json
#   inflating: best_params/checkpoint-2815/trainer_state.json
#    creating: best_params/checkpoint-1000/
#   inflating: best_params/checkpoint-1000/adapter_model.safetensors
#   inflating: best_params/checkpoint-1000/rng_state.pth
#   inflating: best_params/checkpoint-1000/tokenizer_config.json
#   inflating: best_params/checkpoint-1000/special_tokens_map.json
#   inflating: best_params/checkpoint-1000/optimizer.pt
#   inflating: best_params/checkpoint-1000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-1000/scheduler.pt
#   inflating: best_params/checkpoint-1000/tokenizer.json
#   inflating: best_params/checkpoint-1000/README.md
#   inflating: best_params/checkpoint-1000/training_args.bin
#   inflating: best_params/checkpoint-1000/adapter_config.json
#   inflating: best_params/checkpoint-1000/vocab.txt
#   inflating: best_params/checkpoint-1000/trainer_state.json
#    creating: best_params/checkpoint-8500/
#   inflating: best_params/checkpoint-8500/adapter_model.safetensors
#   inflating: best_params/checkpoint-8500/rng_state.pth
#   inflating: best_params/checkpoint-8500/tokenizer_config.json
#   inflating: best_params/checkpoint-8500/special_tokens_map.json
#   inflating: best_params/checkpoint-8500/optimizer.pt
#   inflating: best_params/checkpoint-8500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-8500/scheduler.pt
#   inflating: best_params/checkpoint-8500/tokenizer.json
#   inflating: best_params/checkpoint-8500/README.md
#   inflating: best_params/checkpoint-8500/training_args.bin
#   inflating: best_params/checkpoint-8500/adapter_config.json
#   inflating: best_params/checkpoint-8500/vocab.txt
#   inflating: best_params/checkpoint-8500/trainer_state.json
#   inflating: best_params/best_params.xlsx
#    creating: best_params/checkpoint-987/
#   inflating: best_params/checkpoint-987/adapter_model.safetensors
#   inflating: best_params/checkpoint-987/rng_state.pth
#   inflating: best_params/checkpoint-987/tokenizer_config.json
#   inflating: best_params/checkpoint-987/special_tokens_map.json
#   inflating: best_params/checkpoint-987/optimizer.pt
#   inflating: best_params/checkpoint-987/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-987/scheduler.pt
#   inflating: best_params/checkpoint-987/tokenizer.json
#   inflating: best_params/checkpoint-987/README.md
#   inflating: best_params/checkpoint-987/training_args.bin
#   inflating: best_params/checkpoint-987/adapter_config.json
#   inflating: best_params/checkpoint-987/trainer_state.json
#    creating: best_params/checkpoint-141/
#   inflating: best_params/checkpoint-141/adapter_model.safetensors
#   inflating: best_params/checkpoint-141/rng_state.pth
#   inflating: best_params/checkpoint-141/tokenizer_config.json
#   inflating: best_params/checkpoint-141/special_tokens_map.json
#   inflating: best_params/checkpoint-141/optimizer.pt
#   inflating: best_params/checkpoint-141/scheduler.pt
#   inflating: best_params/checkpoint-141/tokenizer.json
#   inflating: best_params/checkpoint-141/README.md
#   inflating: best_params/checkpoint-141/training_args.bin
#   inflating: best_params/checkpoint-141/adapter_config.json
#   inflating: best_params/checkpoint-141/vocab.txt
#   inflating: best_params/checkpoint-141/trainer_state.json
#    creating: best_params/checkpoint-10000/
#   inflating: best_params/checkpoint-10000/adapter_model.safetensors
#   inflating: best_params/checkpoint-10000/rng_state.pth
#   inflating: best_params/checkpoint-10000/tokenizer_config.json
#   inflating: best_params/checkpoint-10000/special_tokens_map.json
#   inflating: best_params/checkpoint-10000/optimizer.pt
#   inflating: best_params/checkpoint-10000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-10000/scheduler.pt
#   inflating: best_params/checkpoint-10000/tokenizer.json
#   inflating: best_params/checkpoint-10000/README.md
#   inflating: best_params/checkpoint-10000/training_args.bin
#   inflating: best_params/checkpoint-10000/adapter_config.json
#   inflating: best_params/checkpoint-10000/vocab.txt
#   inflating: best_params/checkpoint-10000/trainer_state.json
#    creating: best_params/checkpoint-11250/
#   inflating: best_params/checkpoint-11250/adapter_model.safetensors
#   inflating: best_params/checkpoint-11250/rng_state.pth
#   inflating: best_params/checkpoint-11250/tokenizer_config.json
#   inflating: best_params/checkpoint-11250/special_tokens_map.json
#   inflating: best_params/checkpoint-11250/optimizer.pt
#   inflating: best_params/checkpoint-11250/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-11250/scheduler.pt
#   inflating: best_params/checkpoint-11250/tokenizer.json
#   inflating: best_params/checkpoint-11250/README.md
#   inflating: best_params/checkpoint-11250/training_args.bin
#   inflating: best_params/checkpoint-11250/adapter_config.json
#   inflating: best_params/checkpoint-11250/vocab.txt
#   inflating: best_params/checkpoint-11250/trainer_state.json
#    creating: best_params/checkpoint-11000/
#   inflating: best_params/checkpoint-11000/adapter_model.safetensors
#   inflating: best_params/checkpoint-11000/rng_state.pth
#   inflating: best_params/checkpoint-11000/tokenizer_config.json
#   inflating: best_params/checkpoint-11000/special_tokens_map.json
#   inflating: best_params/checkpoint-11000/optimizer.pt
#   inflating: best_params/checkpoint-11000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-11000/scheduler.pt
#   inflating: best_params/checkpoint-11000/tokenizer.json
#   inflating: best_params/checkpoint-11000/README.md
#   inflating: best_params/checkpoint-11000/training_args.bin
#   inflating: best_params/checkpoint-11000/adapter_config.json
#   inflating: best_params/checkpoint-11000/vocab.txt
#   inflating: best_params/checkpoint-11000/trainer_state.json
#    creating: best_params/checkpoint-9500/
#   inflating: best_params/checkpoint-9500/adapter_model.safetensors
#   inflating: best_params/checkpoint-9500/rng_state.pth
#   inflating: best_params/checkpoint-9500/tokenizer_config.json
#   inflating: best_params/checkpoint-9500/special_tokens_map.json
#   inflating: best_params/checkpoint-9500/optimizer.pt
#   inflating: best_params/checkpoint-9500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-9500/scheduler.pt
#   inflating: best_params/checkpoint-9500/tokenizer.json
#   inflating: best_params/checkpoint-9500/README.md
#   inflating: best_params/checkpoint-9500/training_args.bin
#   inflating: best_params/checkpoint-9500/adapter_config.json
#   inflating: best_params/checkpoint-9500/vocab.txt
#   inflating: best_params/checkpoint-9500/trainer_state.json
#    creating: best_params/checkpoint-10500/
#   inflating: best_params/checkpoint-10500/adapter_model.safetensors
#   inflating: best_params/checkpoint-10500/rng_state.pth
#   inflating: best_params/checkpoint-10500/tokenizer_config.json
#   inflating: best_params/checkpoint-10500/special_tokens_map.json
#   inflating: best_params/checkpoint-10500/optimizer.pt
#   inflating: best_params/checkpoint-10500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-10500/scheduler.pt
#   inflating: best_params/checkpoint-10500/tokenizer.json
#   inflating: best_params/checkpoint-10500/README.md
#   inflating: best_params/checkpoint-10500/training_args.bin
#   inflating: best_params/checkpoint-10500/adapter_config.json
#   inflating: best_params/checkpoint-10500/vocab.txt
#   inflating: best_params/checkpoint-10500/trainer_state.json
#   inflating: best_params/p-xlm-r-base.json
#    creating: best_params/checkpoint-1125/
#   inflating: best_params/checkpoint-1125/adapter_model.safetensors
#   inflating: best_params/checkpoint-1125/rng_state.pth
#   inflating: best_params/checkpoint-1125/tokenizer_config.json
#   inflating: best_params/checkpoint-1125/special_tokens_map.json
#   inflating: best_params/checkpoint-1125/optimizer.pt
#   inflating: best_params/checkpoint-1125/scheduler.pt
#   inflating: best_params/checkpoint-1125/tokenizer.json
#   inflating: best_params/checkpoint-1125/README.md
#   inflating: best_params/checkpoint-1125/training_args.bin
#   inflating: best_params/checkpoint-1125/adapter_config.json
#   inflating: best_params/checkpoint-1125/vocab.txt
#   inflating: best_params/checkpoint-1125/trainer_state.json
#    creating: best_params/checkpoint-7875/
#   inflating: best_params/checkpoint-7875/adapter_model.safetensors
#   inflating: best_params/checkpoint-7875/rng_state.pth
#   inflating: best_params/checkpoint-7875/tokenizer_config.json
#   inflating: best_params/checkpoint-7875/special_tokens_map.json
#   inflating: best_params/checkpoint-7875/optimizer.pt
#   inflating: best_params/checkpoint-7875/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-7875/scheduler.pt
#   inflating: best_params/checkpoint-7875/tokenizer.json
#   inflating: best_params/checkpoint-7875/README.md
#   inflating: best_params/checkpoint-7875/training_args.bin
#   inflating: best_params/checkpoint-7875/adapter_config.json
#   inflating: best_params/checkpoint-7875/trainer_state.json
#   inflating: best_params/mbert.json
#    creating: best_params/checkpoint-8000/
#   inflating: best_params/checkpoint-8000/adapter_model.safetensors
#   inflating: best_params/checkpoint-8000/rng_state.pth
#   inflating: best_params/checkpoint-8000/tokenizer_config.json
#   inflating: best_params/checkpoint-8000/special_tokens_map.json
#   inflating: best_params/checkpoint-8000/optimizer.pt
#   inflating: best_params/checkpoint-8000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-8000/scheduler.pt
#   inflating: best_params/checkpoint-8000/tokenizer.json
#   inflating: best_params/checkpoint-8000/README.md
#   inflating: best_params/checkpoint-8000/training_args.bin
#   inflating: best_params/checkpoint-8000/adapter_config.json
#   inflating: best_params/checkpoint-8000/vocab.txt
#   inflating: best_params/checkpoint-8000/trainer_state.json
#    creating: best_params/checkpoint-1974/
#   inflating: best_params/checkpoint-1974/adapter_model.safetensors
#   inflating: best_params/checkpoint-1974/rng_state.pth
#   inflating: best_params/checkpoint-1974/tokenizer_config.json
#   inflating: best_params/checkpoint-1974/special_tokens_map.json
#   inflating: best_params/checkpoint-1974/optimizer.pt
#   inflating: best_params/checkpoint-1974/scheduler.pt
#   inflating: best_params/checkpoint-1974/tokenizer.json
#   inflating: best_params/checkpoint-1974/README.md
#   inflating: best_params/checkpoint-1974/training_args.bin
#   inflating: best_params/checkpoint-1974/adapter_config.json
#   inflating: best_params/checkpoint-1974/vocab.txt
#   inflating: best_params/checkpoint-1974/trainer_state.json
#   inflating: best_params/xlm-r-large.json
#    creating: best_params/checkpoint-9000/
#   inflating: best_params/checkpoint-9000/adapter_model.safetensors
#   inflating: best_params/checkpoint-9000/rng_state.pth
#   inflating: best_params/checkpoint-9000/tokenizer_config.json
#   inflating: best_params/checkpoint-9000/special_tokens_map.json
#   inflating: best_params/checkpoint-9000/optimizer.pt
#   inflating: best_params/checkpoint-9000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-9000/scheduler.pt
#   inflating: best_params/checkpoint-9000/tokenizer.json
#   inflating: best_params/checkpoint-9000/README.md
#   inflating: best_params/checkpoint-9000/training_args.bin
#   inflating: best_params/checkpoint-9000/adapter_config.json
#   inflating: best_params/checkpoint-9000/vocab.txt
#   inflating: best_params/checkpoint-9000/trainer_state.json
#   inflating: best_params/p-mbert.json
#    creating: best_params/checkpoint-5067/
#   inflating: best_params/checkpoint-5067/adapter_model.safetensors
#   inflating: best_params/checkpoint-5067/rng_state.pth
#   inflating: best_params/checkpoint-5067/tokenizer_config.json
#   inflating: best_params/checkpoint-5067/special_tokens_map.json
#   inflating: best_params/checkpoint-5067/optimizer.pt
#   inflating: best_params/checkpoint-5067/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-5067/scheduler.pt
#   inflating: best_params/checkpoint-5067/tokenizer.json
#   inflating: best_params/checkpoint-5067/README.md
#   inflating: best_params/checkpoint-5067/training_args.bin
#   inflating: best_params/checkpoint-5067/adapter_config.json
#   inflating: best_params/checkpoint-5067/vocab.txt
#   inflating: best_params/checkpoint-5067/trainer_state.json
#   inflating: best_params/indobertweet.json
#    creating: best_params/.ipynb_checkpoints/
#   inflating: best_params/.ipynb_checkpoints/get_best_params-checkpoint.ipynb
#    creating: best_params/checkpoint-5625/
#   inflating: best_params/checkpoint-5625/adapter_model.safetensors
#   inflating: best_params/checkpoint-5625/rng_state.pth
#   inflating: best_params/checkpoint-5625/tokenizer_config.json
#   inflating: best_params/checkpoint-5625/special_tokens_map.json
#   inflating: best_params/checkpoint-5625/optimizer.pt
#   inflating: best_params/checkpoint-5625/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-5625/scheduler.pt
#   inflating: best_params/checkpoint-5625/tokenizer.json
#   inflating: best_params/checkpoint-5625/README.md
#   inflating: best_params/checkpoint-5625/training_args.bin
#   inflating: best_params/checkpoint-5625/adapter_config.json
#   inflating: best_params/checkpoint-5625/trainer_state.json
#    creating: best_params/checkpoint-2256/
#   inflating: best_params/checkpoint-2256/adapter_model.safetensors
#   inflating: best_params/checkpoint-2256/rng_state.pth
#   inflating: best_params/checkpoint-2256/tokenizer_config.json
#   inflating: best_params/checkpoint-2256/special_tokens_map.json
#   inflating: best_params/checkpoint-2256/optimizer.pt
#   inflating: best_params/checkpoint-2256/scheduler.pt
#   inflating: best_params/checkpoint-2256/tokenizer.json
#   inflating: best_params/checkpoint-2256/README.md
#   inflating: best_params/checkpoint-2256/training_args.bin
#   inflating: best_params/checkpoint-2256/adapter_config.json
#   inflating: best_params/checkpoint-2256/vocab.txt
#   inflating: best_params/checkpoint-2256/trainer_state.json
#    creating: best_params/checkpoint-3941/
#   inflating: best_params/checkpoint-3941/adapter_model.safetensors
#   inflating: best_params/checkpoint-3941/rng_state.pth
#   inflating: best_params/checkpoint-3941/tokenizer_config.json
#   inflating: best_params/checkpoint-3941/special_tokens_map.json
#   inflating: best_params/checkpoint-3941/optimizer.pt
#   inflating: best_params/checkpoint-3941/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-3941/scheduler.pt
#   inflating: best_params/checkpoint-3941/tokenizer.json
#   inflating: best_params/checkpoint-3941/README.md
#   inflating: best_params/checkpoint-3941/training_args.bin
#   inflating: best_params/checkpoint-3941/adapter_config.json
#   inflating: best_params/checkpoint-3941/trainer_state.json
#    creating: best_params/checkpoint-4500/
#   inflating: best_params/checkpoint-4500/adapter_model.safetensors
#   inflating: best_params/checkpoint-4500/rng_state.pth
#   inflating: best_params/checkpoint-4500/tokenizer_config.json
#   inflating: best_params/checkpoint-4500/special_tokens_map.json
#   inflating: best_params/checkpoint-4500/optimizer.pt
#   inflating: best_params/checkpoint-4500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-4500/scheduler.pt
#   inflating: best_params/checkpoint-4500/tokenizer.json
#   inflating: best_params/checkpoint-4500/README.md
#   inflating: best_params/checkpoint-4500/training_args.bin
#   inflating: best_params/checkpoint-4500/adapter_config.json
#   inflating: best_params/checkpoint-4500/vocab.txt
#   inflating: best_params/checkpoint-4500/trainer_state.json
#    creating: best_params/checkpoint-6000/
#   inflating: best_params/checkpoint-6000/adapter_model.safetensors
#   inflating: best_params/checkpoint-6000/rng_state.pth
#   inflating: best_params/checkpoint-6000/tokenizer_config.json
#   inflating: best_params/checkpoint-6000/special_tokens_map.json
#   inflating: best_params/checkpoint-6000/optimizer.pt
#   inflating: best_params/checkpoint-6000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-6000/scheduler.pt
#   inflating: best_params/checkpoint-6000/tokenizer.json
#   inflating: best_params/checkpoint-6000/README.md
#   inflating: best_params/checkpoint-6000/training_args.bin
#   inflating: best_params/checkpoint-6000/adapter_config.json
#   inflating: best_params/checkpoint-6000/vocab.txt
#   inflating: best_params/checkpoint-6000/trainer_state.json
#   inflating: best_params/p-xlm-r-large.json
#    creating: best_params/checkpoint-2250/
#   inflating: best_params/checkpoint-2250/adapter_model.safetensors
#   inflating: best_params/checkpoint-2250/rng_state.pth
#   inflating: best_params/checkpoint-2250/tokenizer_config.json
#   inflating: best_params/checkpoint-2250/special_tokens_map.json
#   inflating: best_params/checkpoint-2250/optimizer.pt
#   inflating: best_params/checkpoint-2250/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-2250/scheduler.pt
#   inflating: best_params/checkpoint-2250/tokenizer.json
#   inflating: best_params/checkpoint-2250/README.md
#   inflating: best_params/checkpoint-2250/training_args.bin
#   inflating: best_params/checkpoint-2250/adapter_config.json
#   inflating: best_params/checkpoint-2250/vocab.txt
#   inflating: best_params/checkpoint-2250/trainer_state.json
#   inflating: best_params/get_best_params.ipynb
#    creating: best_params/checkpoint-2000/
#   inflating: best_params/checkpoint-2000/adapter_model.safetensors
#   inflating: best_params/checkpoint-2000/rng_state.pth
#   inflating: best_params/checkpoint-2000/tokenizer_config.json
#   inflating: best_params/checkpoint-2000/special_tokens_map.json
#   inflating: best_params/checkpoint-2000/optimizer.pt
#   inflating: best_params/checkpoint-2000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-2000/scheduler.pt
#   inflating: best_params/checkpoint-2000/tokenizer.json
#   inflating: best_params/checkpoint-2000/README.md
#   inflating: best_params/checkpoint-2000/training_args.bin
#   inflating: best_params/checkpoint-2000/adapter_config.json
#   inflating: best_params/checkpoint-2000/vocab.txt
#   inflating: best_params/checkpoint-2000/trainer_state.json
#    creating: best_params/checkpoint-10125/
#   inflating: best_params/checkpoint-10125/adapter_model.safetensors
#   inflating: best_params/checkpoint-10125/rng_state.pth
#   inflating: best_params/checkpoint-10125/tokenizer_config.json
#   inflating: best_params/checkpoint-10125/special_tokens_map.json
#   inflating: best_params/checkpoint-10125/optimizer.pt
#   inflating: best_params/checkpoint-10125/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-10125/scheduler.pt
#   inflating: best_params/checkpoint-10125/tokenizer.json
#   inflating: best_params/checkpoint-10125/README.md
#   inflating: best_params/checkpoint-10125/training_args.bin
#   inflating: best_params/checkpoint-10125/adapter_config.json
#   inflating: best_params/checkpoint-10125/trainer_state.json
#    creating: best_params/checkpoint-1500/
#   inflating: best_params/checkpoint-1500/adapter_model.safetensors
#   inflating: best_params/checkpoint-1500/rng_state.pth
#   inflating: best_params/checkpoint-1500/tokenizer_config.json
#   inflating: best_params/checkpoint-1500/special_tokens_map.json
#   inflating: best_params/checkpoint-1500/optimizer.pt
#   inflating: best_params/checkpoint-1500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-1500/scheduler.pt
#   inflating: best_params/checkpoint-1500/tokenizer.json
#   inflating: best_params/checkpoint-1500/README.md
#   inflating: best_params/checkpoint-1500/training_args.bin
#   inflating: best_params/checkpoint-1500/adapter_config.json
#   inflating: best_params/checkpoint-1500/vocab.txt
#   inflating: best_params/checkpoint-1500/trainer_state.json
#    creating: best_params/runs/
#    creating: best_params/runs/May18_08-42-14_9a2a45d00125/
#   inflating: best_params/runs/May18_08-42-14_9a2a45d00125/events.out.tfevents.1779093735.9a2a45d00125.11159.8
#    creating: best_params/runs/May18_09-07-52_9a2a45d00125/
#   inflating: best_params/runs/May18_09-07-52_9a2a45d00125/events.out.tfevents.1779095275.9a2a45d00125.39056.0
#    creating: best_params/runs/May18_09-42-04_9a2a45d00125/
#   inflating: best_params/runs/May18_09-42-04_9a2a45d00125/events.out.tfevents.1779097325.9a2a45d00125.39056.8
#    creating: best_params/runs/May18_07-07-25_9a2a45d00125/
#   inflating: best_params/runs/May18_07-07-25_9a2a45d00125/events.out.tfevents.1779088046.9a2a45d00125.1810.6
#    creating: best_params/runs/May18_10-06-20_9a2a45d00125/
#   inflating: best_params/runs/May18_10-06-20_9a2a45d00125/events.out.tfevents.1779098781.9a2a45d00125.51836.4
#    creating: best_params/runs/May18_10-17-26_9a2a45d00125/
#   inflating: best_params/runs/May18_10-17-26_9a2a45d00125/events.out.tfevents.1779099447.9a2a45d00125.51836.8
#    creating: best_params/runs/May18_08-14-36_9a2a45d00125/
#   inflating: best_params/runs/May18_08-14-36_9a2a45d00125/events.out.tfevents.1779092077.9a2a45d00125.11159.5
#    creating: best_params/runs/May18_07-17-59_9a2a45d00125/
#   inflating: best_params/runs/May18_07-17-59_9a2a45d00125/events.out.tfevents.1779088679.9a2a45d00125.1810.9
#    creating: best_params/runs/May18_10-01-32_9a2a45d00125/
#   inflating: best_params/runs/May18_10-01-32_9a2a45d00125/events.out.tfevents.1779098493.9a2a45d00125.51836.1
#    creating: best_params/runs/May18_06-51-11_9a2a45d00125/
#   inflating: best_params/runs/May18_06-51-11_9a2a45d00125/events.out.tfevents.1779087072.9a2a45d00125.1810.2
#    creating: best_params/runs/May18_10-02-29_9a2a45d00125/
#   inflating: best_params/runs/May18_10-02-29_9a2a45d00125/events.out.tfevents.1779098549.9a2a45d00125.51836.2
#    creating: best_params/runs/May18_09-48-23_9a2a45d00125/
#   inflating: best_params/runs/May18_09-48-23_9a2a45d00125/events.out.tfevents.1779097703.9a2a45d00125.39056.9
#    creating: best_params/runs/May18_06-50-35_9a2a45d00125/
#   inflating: best_params/runs/May18_06-50-35_9a2a45d00125/events.out.tfevents.1779087036.9a2a45d00125.1810.1
#    creating: best_params/runs/May18_10-13-25_9a2a45d00125/
#   inflating: best_params/runs/May18_10-13-25_9a2a45d00125/events.out.tfevents.1779099205.9a2a45d00125.51836.7
#    creating: best_params/runs/May18_07-09-06_9a2a45d00125/
#   inflating: best_params/runs/May18_07-09-06_9a2a45d00125/events.out.tfevents.1779088147.9a2a45d00125.1810.7
#    creating: best_params/runs/May18_07-38-48_9a2a45d00125/
#   inflating: best_params/runs/May18_07-38-48_9a2a45d00125/events.out.tfevents.1779089929.9a2a45d00125.11159.2
#    creating: best_params/runs/May18_08-23-39_9a2a45d00125/
#   inflating: best_params/runs/May18_08-23-39_9a2a45d00125/events.out.tfevents.1779092620.9a2a45d00125.11159.6
#    creating: best_params/runs/May18_07-49-55_9a2a45d00125/
#   inflating: best_params/runs/May18_07-49-55_9a2a45d00125/events.out.tfevents.1779090596.9a2a45d00125.11159.3
#    creating: best_params/runs/May18_09-22-57_9a2a45d00125/
#   inflating: best_params/runs/May18_09-22-57_9a2a45d00125/events.out.tfevents.1779096178.9a2a45d00125.39056.4
#    creating: best_params/runs/May18_09-18-27_9a2a45d00125/
#   inflating: best_params/runs/May18_09-18-27_9a2a45d00125/events.out.tfevents.1779095908.9a2a45d00125.39056.3
#    creating: best_params/runs/May18_10-05-42_9a2a45d00125/
#   inflating: best_params/runs/May18_10-05-42_9a2a45d00125/events.out.tfevents.1779098743.9a2a45d00125.51836.3
#    creating: best_params/runs/May18_09-31-47_9a2a45d00125/
#   inflating: best_params/runs/May18_09-31-47_9a2a45d00125/events.out.tfevents.1779096707.9a2a45d00125.39056.5
#    creating: best_params/runs/May18_08-34-15_9a2a45d00125/
#   inflating: best_params/runs/May18_08-34-15_9a2a45d00125/events.out.tfevents.1779093256.9a2a45d00125.11159.7
#    creating: best_params/runs/May18_10-08-06_9a2a45d00125/
#   inflating: best_params/runs/May18_10-08-06_9a2a45d00125/events.out.tfevents.1779098886.9a2a45d00125.51836.6
#    creating: best_params/runs/May18_07-17-17_9a2a45d00125/
#   inflating: best_params/runs/May18_07-17-17_9a2a45d00125/events.out.tfevents.1779088638.9a2a45d00125.1810.8
#    creating: best_params/runs/May18_07-20-37_9a2a45d00125/
#   inflating: best_params/runs/May18_07-20-37_9a2a45d00125/events.out.tfevents.1779088840.9a2a45d00125.11159.0
#    creating: best_params/runs/May18_09-34-27_9a2a45d00125/
#   inflating: best_params/runs/May18_09-34-27_9a2a45d00125/events.out.tfevents.1779096868.9a2a45d00125.39056.6
#    creating: best_params/runs/May18_07-35-08_9a2a45d00125/
#   inflating: best_params/runs/May18_07-35-08_9a2a45d00125/events.out.tfevents.1779089709.9a2a45d00125.11159.1
#    creating: best_params/runs/May18_06-57-31_9a2a45d00125/
#   inflating: best_params/runs/May18_06-57-31_9a2a45d00125/events.out.tfevents.1779087451.9a2a45d00125.1810.4
#    creating: best_params/runs/May18_07-04-06_9a2a45d00125/
#   inflating: best_params/runs/May18_07-04-06_9a2a45d00125/events.out.tfevents.1779087846.9a2a45d00125.1810.5
#    creating: best_params/runs/May18_09-08-38_9a2a45d00125/
#   inflating: best_params/runs/May18_09-08-38_9a2a45d00125/events.out.tfevents.1779095319.9a2a45d00125.39056.1
#    creating: best_params/runs/May18_08-10-54_9a2a45d00125/
#   inflating: best_params/runs/May18_08-10-54_9a2a45d00125/events.out.tfevents.1779091855.9a2a45d00125.11159.4
#    creating: best_params/runs/May18_09-36-18_9a2a45d00125/
#   inflating: best_params/runs/May18_09-36-18_9a2a45d00125/events.out.tfevents.1779096979.9a2a45d00125.39056.7
#    creating: best_params/runs/May18_10-07-28_9a2a45d00125/
#   inflating: best_params/runs/May18_10-07-28_9a2a45d00125/events.out.tfevents.1779098848.9a2a45d00125.51836.5
#    creating: best_params/runs/May18_10-22-01_9a2a45d00125/
#   inflating: best_params/runs/May18_10-22-01_9a2a45d00125/events.out.tfevents.1779099722.9a2a45d00125.51836.9
#    creating: best_params/runs/May18_06-45-11_9a2a45d00125/
#   inflating: best_params/runs/May18_06-45-11_9a2a45d00125/events.out.tfevents.1779086714.9a2a45d00125.1810.0
#    creating: best_params/runs/May18_09-56-45_9a2a45d00125/
#   inflating: best_params/runs/May18_09-56-45_9a2a45d00125/events.out.tfevents.1779098207.9a2a45d00125.51836.0
#    creating: best_params/runs/May18_08-54-56_9a2a45d00125/
#   inflating: best_params/runs/May18_08-54-56_9a2a45d00125/events.out.tfevents.1779094497.9a2a45d00125.11159.9
#    creating: best_params/runs/May18_06-51-47_9a2a45d00125/
#   inflating: best_params/runs/May18_06-51-47_9a2a45d00125/events.out.tfevents.1779087107.9a2a45d00125.1810.3
#    creating: best_params/runs/May18_09-13-06_9a2a45d00125/
#   inflating: best_params/runs/May18_09-13-06_9a2a45d00125/events.out.tfevents.1779095586.9a2a45d00125.39056.2
#    creating: best_params/checkpoint-3000/
#   inflating: best_params/checkpoint-3000/adapter_model.safetensors
#   inflating: best_params/checkpoint-3000/rng_state.pth
#   inflating: best_params/checkpoint-3000/tokenizer_config.json
#   inflating: best_params/checkpoint-3000/special_tokens_map.json
#   inflating: best_params/checkpoint-3000/optimizer.pt
#   inflating: best_params/checkpoint-3000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-3000/scheduler.pt
#   inflating: best_params/checkpoint-3000/tokenizer.json
#   inflating: best_params/checkpoint-3000/README.md
#   inflating: best_params/checkpoint-3000/training_args.bin
#   inflating: best_params/checkpoint-3000/adapter_config.json
#   inflating: best_params/checkpoint-3000/vocab.txt
#   inflating: best_params/checkpoint-3000/trainer_state.json
#  extracting: best_params/best_params_archive.zip
#    creating: best_params/checkpoint-5500/
#   inflating: best_params/checkpoint-5500/adapter_model.safetensors
#   inflating: best_params/checkpoint-5500/rng_state.pth
#   inflating: best_params/checkpoint-5500/tokenizer_config.json
#   inflating: best_params/checkpoint-5500/special_tokens_map.json
#   inflating: best_params/checkpoint-5500/optimizer.pt
#   inflating: best_params/checkpoint-5500/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-5500/scheduler.pt
#   inflating: best_params/checkpoint-5500/tokenizer.json
#   inflating: best_params/checkpoint-5500/README.md
#   inflating: best_params/checkpoint-5500/training_args.bin
#   inflating: best_params/checkpoint-5500/adapter_config.json
#   inflating: best_params/checkpoint-5500/vocab.txt
#   inflating: best_params/checkpoint-5500/trainer_state.json
#    creating: best_params/checkpoint-7000/
#   inflating: best_params/checkpoint-7000/adapter_model.safetensors
#   inflating: best_params/checkpoint-7000/rng_state.pth
#   inflating: best_params/checkpoint-7000/tokenizer_config.json
#   inflating: best_params/checkpoint-7000/special_tokens_map.json
#   inflating: best_params/checkpoint-7000/optimizer.pt
#   inflating: best_params/checkpoint-7000/sentencepiece.bpe.model
#   inflating: best_params/checkpoint-7000/scheduler.pt
#   inflating: best_params/checkpoint-7000/tokenizer.json
#   inflating: best_params/checkpoint-7000/README.md
#   inflating: best_params/checkpoint-7000/training_args.bin
#   inflating: best_params/checkpoint-7000/adapter_config.json
#   inflating: best_params/checkpoint-7000/vocab.txt
#   inflating: best_params/checkpoint-7000/trainer_state.json

# %%
# %cd best_params
# Out:
# /content/best_params

# %%
import json
import glob
import os
import pandas as pd

# %%
def get_params(folder_path):
    pattern = '*.json'

    # Create an empty list to store DataFrames
    dfs = []

    # Use glob to get a list of JSON file paths
    json_files = glob.glob(os.path.join(folder_path, pattern))

    # Loop through JSON files
    for json_file_path in json_files:
        with open(json_file_path, 'r') as file:
            data = json.load(file)

            # Split the string by "/" and get the last part
            last_part = json_file_path.split("/")[-1]

            # Remove the ".json" extension to get the model name
            model_name = last_part.replace(".json", "")

            # Extract parameters from the JSON data

            num_train_epochs = data.get("num_train_epochs", "")
            learning_rate = data.get("learning_rate", "")
            per_device_train_batch_size = data.get("per_device_train_batch_size", "")
            per_device_eval_batch_size = data.get("per_device_eval_batch_size", "")
            weight_decay = data.get("weight_decay", "")

            # Create a DataFrame for the current model's parameters
            df = pd.DataFrame({"Model": model_name,
                               "num_train_epochs": num_train_epochs,
                               "learning_rate": learning_rate,
                               "per_device_train_batch_size": per_device_train_batch_size,
                               "per_device_eval_batch_size": per_device_eval_batch_size,
                               "weight_decay": weight_decay},
                                index=[0])

            # Append the DataFrame to the list
            dfs.append(df)

    # Concatenate all DataFrames in the list
    result_df = pd.concat(dfs, ignore_index=True)

    return result_df

# %%
df = get_params('../best_params/')
df
# Out:
#             Model  num_train_epochs  learning_rate  \
# 0         p-mbert                10        0.00005
# 1  p-indobertweet                10        0.00030
# 2    p-xlm-r-base                 9        0.00030
# 3   p-xlm-r-large                 9        0.00030
#
#    per_device_train_batch_size  per_device_eval_batch_size  weight_decay
# 0                            8                          16      0.013383
# 1                           16                          16      0.017613
# 2                            8                          16      0.038195
# 3                           64                          64      0.031011
