# %% [markdown]
# <a href="https://colab.research.google.com/github/Latifmmhd/Augmentasi-Data-Indonesia-Tweet/blob/main/hp_tuning_PEFT_augmented_bnf16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip Emotion-classification-with-PEFT_Augmented_bnf16.zip
# Out:
# Archive:  Emotion-classification-with-PEFT_Augmented_bnf16.zip
#    creating: Emotion-classification-with-PEFT_Augmented_bnf16/
#    creating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/config
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/description
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/HEAD
#    creating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/hooks/
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/hooks/applypatch-msg.sample
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/hooks/commit-msg.sample
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/hooks/fsmonitor-watchman.sample
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/hooks/post-update.sample
#   inflating: Emotion-classification-with-PEFT_Augmented_bnf16/.git/hooks/pre-applypatch.sample
# ...

# %%
# %cd Emotion-classification-with-PEFT_Augmented_bnf16
# Out:
# /content/Emotion-classification-with-PEFT_Augmented_bnf16

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/huggingface/peft (to revision cf04d0353f0343cbf66627228c4495f51669af34) to /tmp/pip-install-p92gxkem/peft_5b12e66c71844d0383174f46776a01ba
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft /tmp/pip-install-p92gxkem/peft_5b12e66c71844d0383174f46776a01ba
#   Running command git rev-parse -q --verify 'sha^cf04d0353f0343cbf66627228c4495f51669af34'
#   Running command git fetch -q https://github.com/huggingface/peft cf04d0353f0343cbf66627228c4495f51669af34
#   Running command git checkout -q cf04d0353f0343cbf66627228c4495f51669af34
#   Resolved https://github.com/huggingface/peft to commit cf04d0353f0343cbf66627228c4495f51669af34
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA A100-SXM4-40GB

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 31.3 MB/s eta 0:00:00
# ...

# %%
# !sed -i 's/\r$//' run_hp_tuning_peft.sh

# %%
# !bash run_hp_tuning_peft.sh
# Out:
# 2026-07-20 01:58:07.405789: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-20 01:58:07.475213: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Train:  8820
# Val:  1890
# Test:  1890
# [I 2026-07-20 01:58:11,807] A new study created in memory with name: hyper-parameter-search
# pytorch_model.bin: 100% 445M/445M [00:04<00:00, 91.9MB/s]
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !zip -r Emotion-classification-with-PEFT_Augmented_bnf16.zip Emotion-classification-with-PEFT_Augmented_bnf16/
# Out:
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/ (stored 0%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/hp_tuning_peft.py (deflated 61%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/requirements.txt (deflated 26%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/ft-with-peft.ipynb (deflated 48%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/bert_fine_tuning_no_peft.py (deflated 65%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/dataset.zip (stored 0%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/hp_tuning_no_peft.py (deflated 61%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/bert_fine_tuning_peft.py (deflated 64%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/run_hp_tuning_peft.sh (deflated 72%)
#   adding: Emotion-classification-with-PEFT_Augmented_bnf16/README.md (deflated 59%)
# ...

# %%
from google.colab import files
files.download('Emotion-classification-with-PEFT_Augmented_bnf16.zip')
