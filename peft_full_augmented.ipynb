# %% [markdown]
# <a href="https://colab.research.google.com/github/Latifmmhd/Augmentasi-Data-Indonesia-Tweet/blob/main/peft_full_augmented.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip Emotion-classification-with-PEFT.zip
# Out:
# Archive:  Emotion-classification-with-PEFT.zip
#    creating: Emotion-classification-with-PEFT/
#    creating: Emotion-classification-with-PEFT/.git/
#   inflating: Emotion-classification-with-PEFT/.git/config
#   inflating: Emotion-classification-with-PEFT/.git/description
#   inflating: Emotion-classification-with-PEFT/.git/HEAD
#    creating: Emotion-classification-with-PEFT/.git/hooks/
#   inflating: Emotion-classification-with-PEFT/.git/hooks/applypatch-msg.sample
#   inflating: Emotion-classification-with-PEFT/.git/hooks/commit-msg.sample
#   inflating: Emotion-classification-with-PEFT/.git/hooks/fsmonitor-watchman.sample
#   inflating: Emotion-classification-with-PEFT/.git/hooks/post-update.sample
#   inflating: Emotion-classification-with-PEFT/.git/hooks/pre-applypatch.sample
#   inflating: Emotion-classification-with-PEFT/.git/hooks/pre-commit.sample
#   inflating: Emotion-classification-with-PEFT/.git/hooks/pre-merge-commit.sample
# ...

# %%
# %cd Emotion-classification-with-PEFT
# Out:
# /content/Emotion-classification-with-PEFT

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/huggingface/peft (to revision cf04d0353f0343cbf66627228c4495f51669af34) to /tmp/pip-install-59ojwhj0/peft_86f40174f138443bad3a21b25101f05b
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft /tmp/pip-install-59ojwhj0/peft_86f40174f138443bad3a21b25101f05b
#   Running command git rev-parse -q --verify 'sha^cf04d0353f0343cbf66627228c4495f51669af34'
#   Running command git fetch -q https://github.com/huggingface/peft cf04d0353f0343cbf66627228c4495f51669af34
#   Running command git checkout -q cf04d0353f0343cbf66627228c4495f51669af34
#   Resolved https://github.com/huggingface/peft to commit cf04d0353f0343cbf66627228c4495f51669af34
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA A100-SXM4-40GB

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 31.9 MB/s eta 0:00:00
# ...

# %%
# Memperbaiki format line-ending (CRLF ke LF) pada bash script
# !sed -i 's/\r$//' run_hp_tuning_peft.sh

# %%
# !bash run_hp_tuning_peft.sh
# Out:
# 2026-07-11 08:56:49.205399: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-07-11 08:56:49.275555: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Train:  8820
# Val:  1890
# Test:  1890
# [I 2026-07-11 08:56:53,530] A new study created in memory with name: hyper-parameter-search
# config.json: 1.10kB [00:00, 5.82MB/s]
# pytorch_model.bin: 100% 445M/445M [00:06<00:00, 72.5MB/s]
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !zip -r Emotion-classification-with-PEFT_compressed.zip Emotion-classification-with-PEFT/
# Out:
#   adding: Emotion-classification-with-PEFT/ (stored 0%)
#   adding: Emotion-classification-with-PEFT/requirements.txt (deflated 26%)
#   adding: Emotion-classification-with-PEFT/run_hp_tuning_no_peft.sh (deflated 72%)
#   adding: Emotion-classification-with-PEFT/hp_tuning_peft.py (deflated 61%)
#   adding: Emotion-classification-with-PEFT/hp_tuning_no_peft.py (deflated 61%)
#   adding: Emotion-classification-with-PEFT/ft-no-peft.ipynb (deflated 46%)
#   adding: Emotion-classification-with-PEFT/README.md (deflated 59%)
#   adding: Emotion-classification-with-PEFT/split-data.ipynb (deflated 72%)
#   adding: Emotion-classification-with-PEFT/dataset/ (stored 0%)
#   adding: Emotion-classification-with-PEFT/dataset/all_data.csv (deflated 62%)
#   adding: Emotion-classification-with-PEFT/dataset/train.csv (deflated 59%)
#   adding: Emotion-classification-with-PEFT/dataset/.ipynb_checkpoints/ (stored 0%)
# ...

# %%
from google.colab import files

files.download('Emotion-classification-with-PEFT_compressed.zip')
